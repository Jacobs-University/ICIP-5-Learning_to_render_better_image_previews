# %%
import tensorflow as tf
from tensorflow.keras.models import save_model
from tensorflow.python.framework import ops
import tensorflow.keras.layers as L
import tensorflow.compat.v1.keras.backend as K
import numpy as np
from sklearn.model_selection import train_test_split
from lfw_dataset import load_lfw_dataset
import matplotlib.pyplot as plt
import keras_utils
import numpy as np

# %%
### Load dataset
    
ATTRS_NAME = "lfw_attributes.txt"  # http://www.cs.columbia.edu/CAVE/databases/pubfig/download/lfw_attributes.txt
IMAGES_NAME = "lfw-deepfunneled.tgz"  # http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz
RAW_IMAGES_NAME = "lfw.tgz"  # http://vis-www.cs.umass.edu/lfw/lfw.tgz

# %%
# !!! remember to clear session/graph if you rebuild your graph to avoid out-of-memory errors !!!
def reset_tf_session():
   K.clear_session()
   ops.reset_default_graph()
   s = K.get_session()
   return s

# %%
# load images
X, attr = load_lfw_dataset(use_raw=True, dimx=32, dimy=32)
IMG_SHAPE = X.shape[1:]

# center images
X = X.astype('float32') / 255.0 - 0.5

# split
X_train, X_test = train_test_split(X, test_size=0.1, random_state=42)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=18983.0), HTML(value='')))

# %%
def show_image(x):
    plt.imshow(np.clip(x + 0.5, 0, 1))

# %%
plt.title('sample images')

for i in range(6):
    plt.subplot(2,3,i+1)
    show_image(X[i])

print("X shape:", X.shape)
print("attr shape:", attr.shape)

# try to free memory
del X
import gc
gc.collect()
# Out:
# X shape: (13143, 32, 32, 3)
# attr shape: (13143, 73)
# 18997

# %%
def build_deep_autoencoder(img_shape, code_size):
    """PCA's deeper brother. See instructions above. Use `code_size` in layer definitions."""
    H,W,C = img_shape
    
    # encoder
    encoder = tf.keras.models.Sequential()
    encoder.add(L.InputLayer(img_shape))
    
    ### YOUR CODE HERE: define encoder as per instructions above ###
    encoder.add(L.Conv2D(filters=32, kernel_size=(3, 3), activation='elu', padding='same'))
    encoder.add(L.MaxPooling2D(pool_size=(2, 2)))
    encoder.add(L.Conv2D(filters=64, kernel_size=(3, 3), activation='elu', padding='same'))
    encoder.add(L.MaxPooling2D(pool_size=(2, 2)))
    encoder.add(L.Conv2D(filters=128, kernel_size=(3, 3), activation='elu', padding='same'))
    encoder.add(L.MaxPooling2D(pool_size=(2, 2)))
    encoder.add(L.Conv2D(filters=256, kernel_size=(3, 3), activation='elu', padding='same'))
    encoder.add(L.MaxPooling2D(pool_size=(2, 2)))
    encoder.add(L.Flatten())
    encoder.add(L.Dense(code_size))

    # decoder
    decoder = tf.keras.models.Sequential()
    decoder.add(L.InputLayer((code_size,)))
    
    ### YOUR CODE HERE: define decoder as per instructions above ###
    decoder.add(L.Dense(2*2*256))
    decoder.add(L.Reshape((2, 2, 256)))
    decoder.add(L.Conv2DTranspose(filters=128, kernel_size=(3, 3), strides=2, activation='elu', padding='same'))
    decoder.add(L.Conv2DTranspose(filters=64, kernel_size=(3, 3), strides=2, activation='elu', padding='same'))
    decoder.add(L.Conv2DTranspose(filters=32, kernel_size=(3, 3), strides=2, activation='elu', padding='same'))
    decoder.add(L.Conv2DTranspose(filters=3, kernel_size=(3, 3), strides=2, activation=None, padding='same'))
    
    return encoder, decoder

# %%
# Check autoencoder shapes along different code_sizes
get_dim = lambda layer: np.prod(layer.output_shape[1:])
for code_size in [1,8,32,128,512]:
    tf.keras.backend.clear_session()
    encoder, decoder = build_deep_autoencoder(IMG_SHAPE, code_size=code_size)
    print("Testing code size %i" % code_size)
    assert encoder.output_shape[1:]==(code_size,),"encoder must output a code of required size"
    assert decoder.output_shape[1:]==IMG_SHAPE,   "decoder must output an image of valid shape"
    assert len(encoder.trainable_weights)>=6,     "encoder must contain at least 3 layers"
    assert len(decoder.trainable_weights)>=6,     "decoder must contain at least 3 layers"
    
    for layer in encoder.layers + decoder.layers:
        assert get_dim(layer) >= code_size, "Encoder layer %s is smaller than bottleneck (%i units)"%(layer.name,get_dim(layer))

print("All tests passed!")
# Out:
# Testing code size 1
# Testing code size 8
# Testing code size 32
# Testing code size 128
# Testing code size 512
# All tests passed!

# %%
tf.keras.backend.clear_session()
encoder, decoder = build_deep_autoencoder(IMG_SHAPE, code_size=32)
encoder.summary()
decoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                32800
# =================================================================
# Total params: 421,216
# Trainable params: 421,216
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              33792
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 4, 4, 128)         295040
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 8, 8, 64)          73792
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 16, 16, 32)        18464
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 32, 32, 3)         867
# =================================================================
# Total params: 421,955
# Trainable params: 421,955
# Non-trainable params: 0
# _________________________________________________________________

# %%
inp = L.Input(IMG_SHAPE)
code = encoder(inp)
reconstruction = decoder(code)

# %%
autoencoder = tf.keras.models.Model(inputs=inp, outputs=reconstruction)
autoencoder.compile(optimizer="adamax", loss='mse')

# %%
# we will save model checkpoints here to continue training in case of kernel death
model_filename = 'autoencoder.{0:03d}.hdf5'
last_finished_epoch = None

#### uncomment below to continue training from model checkpoint
#### fill `last_finished_epoch` with your latest finished epoch
from keras.models import load_model
s = reset_tf_session()
last_finished_epoch = 4
autoencoder = load_model(model_filename.format(last_finished_epoch))
encoder = autoencoder.layers[1]
decoder = autoencoder.layers[2]

# %%
class ModelSaveCallback(tf.keras.callbacks.Callback):
    def __init__(self, file_name):
        super(ModelSaveCallback, self).__init__()
        self.file_name = file_name

    def on_epoch_end(self, epoch, logs=None):
        model_filename = self.file_name.format(epoch)
        save_model(self.model, model_filename)
        print("Model saved in {}".format(model_filename))

# %%
autoencoder.fit(x=X_train, y=X_train, epochs=25,
                validation_data=(X_test, X_test),
                callbacks=[ModelSaveCallback(model_filename)],
                           #keras_utils.TqdmProgressCallback()],
                verbose=1,
                initial_epoch=last_finished_epoch or 0)
# Out:
# Epoch 1/25
# 370/370 [==============================] - 35s 89ms/step - loss: 0.0201 - val_loss: 0.0094
# Model saved in autoencoder.000.hdf5
# Epoch 2/25
# 370/370 [==============================] - 30s 82ms/step - loss: 0.0089 - val_loss: 0.0077
# Model saved in autoencoder.001.hdf5
# Epoch 3/25
# 370/370 [==============================] - 30s 82ms/step - loss: 0.0076 - val_loss: 0.0072
# Model saved in autoencoder.002.hdf5
# Epoch 4/25
# 370/370 [==============================] - 31s 83ms/step - loss: 0.0071 - val_loss: 0.0069
# Model saved in autoencoder.003.hdf5
# Epoch 5/25
# 370/370 [==============================] - 35s 93ms/step - loss: 0.0070 - val_loss: 0.0069
# Model saved in autoencoder.004.hdf5
# Epoch 6/25
# 370/370 [==============================] - 38s 102ms/step - loss: 0.0069 - val_loss: 0.0068
# Model saved in autoencoder.005.hdf5
# Epoch 7/25
# 370/370 [==============================] - 168s 456ms/step - loss: 0.0067 - val_loss: 0.0067
# Model saved in autoencoder.006.hdf5
# Epoch 8/25
# 370/370 [==============================] - 31s 85ms/step - loss: 0.0067 - val_loss: 0.0066
# Model saved in autoencoder.007.hdf5
# Epoch 9/25
# 370/370 [==============================] - 34s 91ms/step - loss: 0.0067 - val_loss: 0.0066
# Model saved in autoencoder.008.hdf5
# Epoch 10/25
# 370/370 [==============================] - 32s 86ms/step - loss: 0.0066 - val_loss: 0.0065
# Model saved in autoencoder.009.hdf5
# Epoch 11/25
# 370/370 [==============================] - 32s 86ms/step - loss: 0.0066 - val_loss: 0.0064
# Model saved in autoencoder.010.hdf5
# Epoch 12/25
# 370/370 [==============================] - 32s 86ms/step - loss: 0.0065 - val_loss: 0.0064
# Model saved in autoencoder.011.hdf5
# Epoch 13/25
# 370/370 [==============================] - 34s 93ms/step - loss: 0.0063 - val_loss: 0.0063
# Model saved in autoencoder.012.hdf5
# Epoch 14/25
# 370/370 [==============================] - 36s 97ms/step - loss: 0.0063 - val_loss: 0.0062
# Model saved in autoencoder.013.hdf5
# Epoch 15/25
# 370/370 [==============================] - 35s 94ms/step - loss: 0.0062 - val_loss: 0.0062
# Model saved in autoencoder.014.hdf5
# Epoch 16/25
# 370/370 [==============================] - 32s 88ms/step - loss: 0.0061 - val_loss: 0.0061
# Model saved in autoencoder.015.hdf5
# Epoch 17/25
# 370/370 [==============================] - 28s 76ms/step - loss: 0.0061 - val_loss: 0.0060
# Model saved in autoencoder.016.hdf5
# Epoch 18/25
# 370/370 [==============================] - 28s 76ms/step - loss: 0.0059 - val_loss: 0.0060
# Model saved in autoencoder.017.hdf5
# Epoch 19/25
# 370/370 [==============================] - 30s 82ms/step - loss: 0.0059 - val_loss: 0.0059
# Model saved in autoencoder.018.hdf5
# Epoch 20/25
# 370/370 [==============================] - 28s 76ms/step - loss: 0.0059 - val_loss: 0.0059
# Model saved in autoencoder.019.hdf5
# Epoch 21/25
# 370/370 [==============================] - 35s 95ms/step - loss: 0.0058 - val_loss: 0.0058
# Model saved in autoencoder.020.hdf5
# Epoch 22/25
# 370/370 [==============================] - 30s 82ms/step - loss: 0.0057 - val_loss: 0.0058
# Model saved in autoencoder.021.hdf5
# Epoch 23/25
# 370/370 [==============================] - 29s 79ms/step - loss: 0.0056 - val_loss: 0.0057
# Model saved in autoencoder.022.hdf5
# Epoch 24/25
# 370/370 [==============================] - 27s 74ms/step - loss: 0.0056 - val_loss: 0.0057
# Model saved in autoencoder.023.hdf5
# Epoch 25/25
# 370/370 [==============================] - 27s 73ms/step - loss: 0.0056 - val_loss: 0.0057
# Model saved in autoencoder.024.hdf5

# %%
def visualize(img,encoder,decoder):
    """Draws original, encoded and decoded images"""
    code = encoder.predict(img[None])[0]  # img[None] is the same as img[np.newaxis, :]
    reco = decoder.predict(code[None])[0]
    
    plt.subplot(1,3,1)
    plt.title("Original")
    show_image(img)

    plt.subplot(1,3,2)
    plt.title("Code")
    plt.imshow(code.reshape([code.shape[-1]//2,-1]))

    plt.subplot(1,3,3)
    plt.title("Reconstructed")
    show_image(reco)
    plt.show()

# %%
reconstruction_mse = autoencoder.evaluate(X_test, X_test, verbose=0)
print("Convolutional autoencoder MSE:", reconstruction_mse)
for i in range(5, 10):
    img = X_test[i]
    visualize(img,encoder,decoder)
# Out:
# Convolutional autoencoder MSE: 0.006867589894682169

# %%
# save trained weights
encoder.save_weights("encoder.h5")
decoder.save_weights("decoder.h5")

# %%
# restore trained weights
tf.keras.backend.clear_session()

encoder, decoder = build_deep_autoencoder(IMG_SHAPE, code_size=32)
encoder.load_weights("encoder.h5")
decoder.load_weights("decoder.h5")

inp = L.Input(IMG_SHAPE)
code = encoder(inp)
reconstruction = decoder(code)

autoencoder = tf.keras.models.Model(inputs=inp, outputs=reconstruction)
autoencoder.compile(optimizer="adamax", loss='mse')

print(autoencoder.evaluate(X_test, X_test, verbose=1))
print(reconstruction_mse)
# Out:
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0069
# 0.006867589894682169
# 0.006867589894682169
